# %%
import pandas as pd  
import pickle 
import numpy as np 
from sqlalchemy import create_engine
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import datetime

# %%
filepath = "/Users/hannahkim/project/project4/LLCP2021.xpt"
df = pd.read_sas(filepath, format = 'xport', encoding = 'utf-8')
df.head()
# Out:
# /var/folders/vl/msb_49ms6zn68_cx7zq3jx4w0000gn/T/ipykernel_17107/1521519329.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df = pd.read_sas(filepath, format = 'xport', encoding = 'utf-8')
# /var/folders/vl/msb_49ms6zn68_cx7zq3jx4w0000gn/T/ipykernel_17107/1521519329.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df = pd.read_sas(filepath, format = 'xport', encoding = 'utf-8')
# ...

# %%
#import to pickle 

df.to_pickle('heart_pickle.pkl')
